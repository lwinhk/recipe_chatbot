# %%
# !pip install pandas
# !pip install scikit-learn joblib
# !pip install sentence-transformers faiss-cpu
# !pip install openai
# Out:
# Requirement already satisfied: pandas in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scikit-learn in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (1.7.2)
# Requirement already satisfied: joblib in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sentence-transformers in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (5.1.2)
# Requirement already satisfied: faiss-cpu in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (1.12.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (2.9.0)
# Requirement already satisfied: scikit-learn in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.10.23)
# Requirement already satisfied: requests in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: openai in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (2.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\lwinh\appdata\local\programs\python\python312\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
# import required dependencies
import pandas as pd
import numpy as np
import uuid
import json
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import faiss, time
from openai import OpenAI
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
import joblib

# %%
# load dataset
dataset = "files/inputs/3A2M_Test.csv"
data = pd.read_csv(dataset)

# %%
print(len(data))
# Out:
# 30000

# %%
# rename default column names
data = data.rename(columns={
    "Unnamed: 0": "row",
    "title": "title",
    "directions": "directions",
    "NER": "ingredients",
    "genre": "genre",
    "label": "label"
})

# %%
# helper functions
def generate_id():
    return str(uuid.uuid4())

def create_summary(recipe):
    summary = f"Recipe Name: {recipe["title"]}\nIngredients: {', '.join(recipe["ingredients"])}\nDirections: {', '.join(recipe["directions"])}\nGenre: {recipe["genre"]}"
    return summary

# %%
# prepare json data from dataset
recipes = []
for _, r in data.iterrows():
    recipes.append({
        "id": generate_id(),
        "row": r["row"],
        "title": r["title"],
        "ingredients": json.loads(r["ingredients"]),
        "directions": json.loads(r["directions"]),
        "genre": r["genre"],
        "label": r["label"]
    })

for r in recipes:
    r["summary"] = create_summary(r)

# %%
print(recipes[0])
# Out:
# {'id': '495e6287-dfc5-437e-95cc-de237626b301', 'row': 0, 'title': 'Reeses Cups(Candy)  ', 'ingredients': ['peanut butter', 'graham cracker crumbs', 'butter', 'powdered sugar', 'chocolate chips'], 'directions': ['Combine first four ingredients and press in 13 x 9-inch ungreased pan.', 'Melt chocolate chips and spread over mixture. Refrigerate for about 20 minutes and cut into pieces before chocolate gets hard.', 'Keep in refrigerator.'], 'genre': 'drinks', 'label': 2, 'summary': 'Recipe Name: Reeses Cups(Candy)  \nIngredients: peanut butter, graham cracker crumbs, butter, powdered sugar, chocolate chips\nDirections: Combine first four ingredients and press in 13 x 9-inch ungreased pan., Melt chocolate chips and spread over mixture. Refrigerate for about 20 minutes and cut into pieces before chocolate gets hard., Keep in refrigerator.\nGenre: drinks'}

# %%
# save recipes to file
with open("files/outputs/recipes.jsonl", "w", encoding="utf-8") as f:
    for r in recipes:
        f.write(json.dumps(r, ensure_ascii=False) + "\n")

# %%
# prepare summeries for embedding
summaries = []

for r in recipes:
    summaries.append(r["summary"])

# %% [markdown]
# ### All MiniLM L6 V2

# %%
# prepare embedding model
embedding_model = "all-MiniLM-L6-v2"
model = SentenceTransformer(embedding_model, device="cpu")

# %%
# prepare embedding function
def embed_summaries(summaries, batch_size=256):
    vectors = []

    for i in tqdm(range(0, len(summaries), batch_size), desc="Embedding"):
        batch = summaries[i:i+batch_size]
        # L2-normalized -> cosine via dot
        embed = model.encode(batch, convert_to_numpy=True, normalize_embeddings=True)
        vectors.append(embed.astype(np.float32))

    return np.vstack(vectors)

# %%
# embed summaries
start_time = time.time()
embeded_summaries = embed_summaries(summaries)
end_time = time.time()
time_taken = end_time - start_time
print(time_taken)

# 1425.6717722415924
# Out:
# Embedding:   0%|          | 0/118 [00:00<?, ?it/s]
# Embedding: 100%|██████████| 118/118 [23:45<00:00, 12.08s/it]
# 1425.6717722415924

# %%
# create FAISS index file
d = embeded_summaries.shape[1]
index = faiss.IndexFlatIP(d)
index.add(embeded_summaries)

# %%
# save index file
index_path = "files/outputs/recipes-index-all-MiniLM-L6-v2.bin"

faiss.write_index(index, index_path)

# %% [markdown]
# ### Text Embedding 3 Small

# %%
embedding_model = "text-embedding-3-small"
openai_api_key = "add-your-open-AI-key"

client = OpenAI(api_key=openai_api_key)

# %%
# prepare embedding function
def embed_summaries(summaries, batch_size=256):
    vectors = []

    for i in tqdm(range(0, len(summaries), batch_size), desc="Embedding"):
        batch = summaries[i:i+batch_size]

        embed = client.embeddings.create(input=batch, model=embedding_model)

        for e in embed.data:
            vectors.append(e.embedding)

    return np.array(vectors, dtype=np.float32)

# %%
start_time = time.time()
embedded_summaries = embed_summaries(summaries)
end_time = time.time()
time_taken = end_time - start_time
print(time_taken)

# 306.5218036174774
# Out:
# Embedding:   0%|          | 0/118 [00:00<?, ?it/s]
# Embedding: 100%|██████████| 118/118 [04:33<00:00,  2.32s/it]
# 306.5218036174774

# %%
# Normalize vectors for cosine similarity
norms = np.linalg.norm(embedded_summaries, axis=1, keepdims=True)
embedded_summaries = embedded_summaries / norms

# create FAISS index file
d = embedded_summaries.shape[1]
index = faiss.IndexFlatIP(d)
index.add(embeded_summaries)

# %%
# save index file
index_path = "files/outputs/recipes-index-text-embedding-3-small.bin"

faiss.write_index(index, index_path)

# %%
vector_path = "files/outputs/recipes-tfidf.joblib"

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2), min_df=1, max_df=0.9)
pipeline = make_pipeline(vectorizer, Normalizer(copy=False))

start_time = time.time()
vectors = pipeline.fit_transform(summaries)
end_time = time.time()

time_taken = end_time - start_time
print(time_taken)

# 10.024590730667114
# Out:
# 10.024590730667114

# %%
joblib.dump({"pipeline": pipeline, "vectors": vectors}, vector_path)
# Out:
# ['files/outputs/recipes-tfidf.joblib']
